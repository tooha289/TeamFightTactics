# %%
# %load 05.data_analysis_visualization\my_init.py
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import folium
import seaborn as sns
from folium.plugins import HeatMap
from matplotlib import font_manager

font_path = 'C:/Windows/Fonts/malgun.ttf'
font_family = font_manager.FontProperties(fname=font_path).get_name()
plt.rcParams['font.family'] = font_family
plt.rcParams['axes.unicode_minus'] = False

pd.options.display.float_format = lambda x: f'{x:.3f}'
pd.options.display.max_rows = 100
pd.options.display.max_columns = 50

# %%
import random

champion_list = ['사미라', '이렐리아', '케일', '말자하', '초가스', '레넥톤', '오리아나', '뽀삐',
                 '티모', '워윅', '갈리오', '소라카']

# 중복을 허용하지 않는 100개의 챔피언 리스트 생성
random_champions = [random.sample(champion_list, k=5) for i in range(50)]
placements = [random.randint(1, 8) for i in range(50)]

print(random_champions)
print(placements)
dictionary = {'champions':random_champions, 'placements':placements}
df = pd.DataFrame(dictionary)
df

# %%
import pandas as pd
import plotly.express as px
from itertools import combinations
from collections import defaultdict
import mplcursors  # 추가

# 각 조합의 평균 순위와 빈도수를 저장할 defaultdict 초기화
combo_data = defaultdict(lambda: {"placements": [], "count": 0})

# 데이터프레임 순회하며 조합의 평균 순위와 빈도수 계산
for index, row in df.iterrows():
    champions = row["champions"]
    placement = row["placements"]

    # 플레이어가 사용한 조합 추가
    combo = tuple(sorted(champions))
    combo_data[combo]["placements"].append(placement)
    combo_data[combo]["count"] += 1

    # 조합의 부분집합들 추가
    for r in range(1, len(champions)):
        for subset in combinations(champions, r):
            subset_combo = tuple(sorted(subset))
            combo_data[subset_combo]["placements"].append(placement)
            combo_data[subset_combo]["count"] += 1

# 각 조합 및 부분집합들의 평균 순위와 빈도수 계산 및 출력
for combo, data in combo_data.items():
    avg_rank = sum(data["placements"]) / data["count"]
    print(f"조합: {combo}, 평균 순위: {avg_rank:.2f}, 빈도수: {data['count']}")


# 각 조합 및 부분집합들의 평균 순위와 빈도수를 데이터프레임으로 변환
result_data = []
for combo, data in combo_data.items():
    avg_rank = sum(data["placements"]) / data["count"]
    result_data.append(
        {"Combination": combo, "AvgRank": avg_rank, "Frequency": data["count"]}
    )
    
result_df = pd.DataFrame(result_data)

# 사이즈 정보 추가
# result_data = []
# for combo, data in combo_data.items():
#     avg_rank = sum(data['placements']) / data['count']
#     result_data.append({'Combination': ', '.join(combo), 'AvgRank': avg_rank, 'Frequency': data['count'], 'Size': 1 / data['count']})



# # 막대 그래프 생성
# plt.figure(figsize=(12, 6))
# plt.bar(result_df['Combination'].apply(', '.join), result_df['AvgRank'], color='blue', alpha=0.7)
# plt.xlabel('Combinations')
# plt.ylabel('Average Placement')
# plt.title('Average Placement by Combinations')
# plt.xticks(rotation=90)
# plt.tight_layout()
# plt.show()

# print(result_df)

# %%
# 점 그래프 생성
fig = px.scatter(
    result_df,
    x="Frequency",
    y="AvgRank",
    size="Frequency",
    hover_name="Combination",
    title="Average Placement vs Frequency",
    labels={
        "Frequency": "Frequency",
        "AvgRank": "Average Placement",
    },
)

# 툴팁 추가
fig.update_traces(hovertemplate='%{hovertext}<br>AvgRank: %{y:.2f}<br>Frequency: %{x}<extra></extra>') 

# 그래프 표시
fig.show()

print(result_df)

# %%
import pandas as pd
import plotly.graph_objects as go
import networkx as nx
from itertools import combinations
from collections import defaultdict

# 주어진 코드와 데이터

# ... (주어진 코드)

# 각 조합과 부분집합들의 관계를 저장할 그래프 생성
graph = nx.Graph()

# 노드 추가 (조합 및 부분집합들)
for combo in combo_data:
    graph.add_node(combo)

# 엣지 추가 (공통된 플레이어를 가진 조합들 간의 연결)
for combo1, data1 in combo_data.items():
    for combo2, data2 in combo_data.items():
        if combo1 != combo2:  # 같은 조합들 간의 연결은 제외
            common_players = set(combo1).intersection(combo2)
            if common_players:
                graph.add_edge(combo1, combo2, weight=len(common_players))

# 네트워크 그래프 시각화
pos = nx.spring_layout(graph)  # 노드의 위치 결정
edge_trace = go.Scatter(
    x=[],
    y=[],
    line=dict(width=0.5, color="#888"),
    hoverinfo="none",
    mode="lines",
)
for edge in graph.edges():
    x0, y0 = pos[edge[0]]
    x1, y1 = pos[edge[1]]
    edge_trace["x"] += tuple([x0, x1, None])
    edge_trace["y"] += tuple([y0, y1, None])

node_trace = go.Scatter(
    x=[],
    y=[],
    text=[],
    mode="markers",
    hoverinfo="text",
    marker=dict(
        showscale=True,
        colorscale="YlGnBu",
        size=10,
    ),
)

for node in graph.nodes():
    x, y = pos[node]
    node_trace["x"] += tuple([x])
    node_trace["y"] += tuple([y])
    node_text = f"Combination: {node}<br>AvgRank: {result_df[result_df['Combination'] == node]['AvgRank'].values[0]:.2f}<br>Frequency: {result_df[result_df['Combination'] == node]['Frequency'].values[0]}"
    node_trace["text"] += tuple([node_text])

fig = go.Figure(data=[edge_trace, node_trace],
                layout=go.Layout(
                    showlegend=False,
                    hovermode="closest",
                ))

fig.show()

# %% [markdown]
# #### 한글화 작업

# %%
import json

file_path = '../json/ko_kr.json'
with open(file_path, 'r') as json_file:
	data_dragon = json.load(json_file)

# %%
data_dragon

# %%
import pandas as pd

items = pd.DataFrame(data_dragon['items'])
items
# Out:
#                                        apiName associatedTraits  \
# 0             TFT7_Consumable_NeekosHelpDragon               []
# 1     TFT9_Augment_BuildingACollectionPlusPlus               []
# 2              TFT9_Augment_Commander_Amplify2               []
# 3            TFT9_Augment_FortuneFavorsTheBold               []
# 4              TFT9_Augment_Commander_Amplify3               []
# ...                                        ...              ...
# 1649                TFT4_Item_OrnnTheCollector               []
# 1650                     TFT_Item_UnusableSlot               []
# 1651                  TFT_Item_HextechGunblade               []
# 1652                     TFT_Item_Hex_Mountain               []
# 1653                TFT7_Item_MirageEmblemItem               []
#
#                                           composition  \
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                                                  []
# ...                                               ...
# 1649                                               []
# 1650                                               []
# 1651  [TFT_Item_BFSword, TFT_Item_NeedlesslyLargeRod]
# 1652                                               []
# 1653       [TFT_Item_NegatronCloak, TFT_Item_Spatula]
#
#                                                    desc  \
# 0                TFT7_Consumable_Description_Dragonling
# 1     다음 @roundsofbonusitems@번의 라운드 시작 시 무작위 조합 아이템을...
# 2                  아군 유닛의 치명타 피해량이 @CritDamage@% 증가합니다.
# 3     플레이어 전투에서 승리하면 추가 구체를 얻습니다. 구체를 얻지 못한 라운드가 많을수...
# 4                  아군 유닛의 치명타 피해량이 @CritDamage@% 증가합니다.
# ...                                                 ...
# 1649  기본 공격 및 스킬로 최대 체력의 @ExecutePercent@%보다 체력이 낮은 ...
# 1650                            이 슬롯에는 아이템을 장착할 수 없습니다.
# 1651  <TFTKeyword>모든 피해 흡혈</TFTKeyword> @OmniVamp@% ...
# 1652               tft_item_description_MountainHexBuff
# 1653  장착 시 신기루 특성 획득<br><br><tftitemrules>[고유 - 중복 적...
#
#                                                 effects  from  \
# 0                                                    {}  None
# 1                   {'Gold': 'null', '{9ce9870c}': 5.0}  None
# 2                                  {'CritDamage': 20.0}  None
# 3                                                    {}  None
# 4                                  {'CritDamage': 30.0}  None
# ...                                                 ...   ...
# 1649  {'AD': 0.20000000298023224, 'CritChance': 30.0...  None
# 1650                                                 {}  None
# 1651  {'AD': 0.10000000149011612, 'AP': 10.0, '{ad16...  None
# 1652                               {'{1bb18b94}': 30.0}  None
# 1653                              {'MagicResist': 20.0}  None
#
#                                                    icon    id  \
# 0     ASSETS/Maps/Particles/TFT/TFT7_Consumable_Drag...  None
# 1     ASSETS/Maps/TFT/Icons/Augments/Hexcore/Buried-...  None
# 2     ASSETS/Maps/TFT/Icons/Augments/Hexcore/Missing...  None
# 3     ASSETS/Maps/TFT/Icons/Augments/Hexcore/Golden-...  None
# 4     ASSETS/Maps/TFT/Icons/Augments/Hexcore/Missing...  None
# ...                                                 ...   ...
# 1649  ASSETS/Maps/Particles/TFT/Item_Icons/Ornn_Item...  None
# 1650  ASSETS/Maps/Particles/TFT/Item_Icons/Placehold...  None
# 1651  ASSETS/Maps/Particles/TFT/Item_Icons/Standard/...  None
# 1652  ASSETS/Maps/Particles/TFT/TFT_Item_Hex_Mountai...  None
# 1653  ASSETS/Maps/Particles/TFT/Item_Icons/Traits/Sp...  None
#
#      incompatibleTraits                             name  unique
# 0                    []  TFT7_Consumable_Name_Dragonling   False
# 1                    []                       파묻힌 보물 III   False
# 2                    []                            증폭 II   False
# 3                    []                     행운은 용감한 자의 편   False
# 4                    []                           증폭 III   False
# ...                 ...                              ...     ...
# 1649                 []                         황금 징수의 총    True
# 1650                 []                      사용할 수 없는 슬롯   False
# 1651                 []                          마법공학 총검   False
# 1652                 []    tft_item_name_MountainHexBuff   False
# 1653      [Set7_Mirage]                           신기루 상징    True
#
# [1654 rows x 11 columns]

# %%
set_data = pd.DataFrame(data_dragon['setData'])
set_data
# Out:
#                                             champions               mutator  \
# 0   [{'ability': {'desc': '블라디미르가 대상에게 @ModifiedDa...        TFTSet7_Stage2
# 1   [{'ability': {'desc': '공허 생물이 현재 스테이지를 기준으로 추가...        TFTTutorialSet
# 2   [{'ability': {'desc': '공허 생물이 현재 스테이지를 기준으로 추가...               TFTSet9
# 3   [{'ability': {'desc': '사일러스가 사슬을 휘둘러 주변 적들에게 <...               TFTSet8
# 4   [{'ability': {'desc': '공허 생물이 현재 스테이지를 기준으로 추가...               TFTSet6
# 5   [{'ability': {'desc': '블라디미르가 대상에게 @ModifiedDa...               TFTSet7
# 6   [{'ability': {'desc': '공허 생물이 현재 스테이지를 기준으로 추가...           TFTEvent_SF
# 7   [{'ability': {'desc': '사일러스가 사슬을 휘둘러 주변 적들에게 <...         TFTSet8_PAIRS
# 8   [{'ability': {'desc': '레오나가 빛의 힘을 불러내어 @Durati...        TFTSet6_Stage2
# 9   [{'ability': {'desc': '사일러스가 사슬을 휘둘러 주변 적들에게 <...        TFTSet8_Stage2
# 10  [{'ability': {'desc': '사일러스가 사슬을 휘둘러 주변 적들에게 <...         TFTSet8_LUNAR
# 11  [{'ability': {'desc': '블라디미르가 대상에게 @ModifiedDa...  TFTSet7_Stage2_PAIRS
# 12  [{'ability': {'desc': '블라디미르가 대상에게 @ModifiedDa...         TFTSet7_PAIRS
# 13  [{'ability': {'desc': '블라디미르가 대상에게 @ModifiedDa...  TFTTURBO_Set7_Stage2
# 14  [{'ability': {'desc': '사일러스가 사슬을 휘둘러 주변 적들에게 <...          TFTTURBOSet8
# 15  [{'ability': {'desc': '사일러스가 사슬을 휘둘러 주변 적들에게 <...  TFTSet8_Stage2_PAIRS
# 16  [{'ability': {'desc': '블라디미르가 대상에게 @ModifiedDa...          TFTTURBOSet7
# 17  [{'ability': {'desc': '공허 생물이 현재 스테이지를 기준으로 추가...          TFTTURBOSet6
# 18  [{'ability': {'desc': '레오나가 빛의 힘을 불러내어 @Durati...  TFTSet6_Stage2_PAIRS
# 19  [{'ability': {'desc': '사일러스가 사슬을 휘둘러 주변 적들에게 <...   TFTTURBOSet8_Stage2
# 20  [{'ability': {'desc': '공허 생물이 현재 스테이지를 기준으로 추가...         TFTSet6_PAIRS
# 21  [{'ability': {'desc': '공허 생물이 현재 스테이지를 기준으로 추가...         TFTSet9_TURBO
# 22  [{'ability': {'desc': '공허 생물이 현재 스테이지를 기준으로 추가...         TFTSet9_PAIRS
#
#           name  number                                             traits
# 0         Set7       7  [{'apiName': 'Set7_Cannoneer', 'desc': '5번째 공격...
# 1   TutorialV2       1  [{'apiName': 'TFTTutorial_Hextech', 'desc': '전...
# 2         Set9       9  [{'apiName': 'Set9_Bastion', 'desc': '요새 챔피언이 ...
# 3         Set8       8  [{'apiName': 'Set8_Civilian', 'desc': '민간인이 생존...
# 4         Set6       6  [{'apiName': 'Set6_Rivals', 'desc': '이 특성은 정확히...
# 5         Set7       7  [{'apiName': 'Set7_Cannoneer', 'desc': '5번째 공격...
# 6         Set9       9  [{'apiName': 'Set9_Bastion', 'desc': '요새 챔피언이 ...
# 7         Set8       8  [{'apiName': 'Set8_Civilian', 'desc': '민간인이 생존...
# 8         Set6       6  [{'apiName': 'Set6_Rivals', 'desc': '이 특성은 정확히...
# 9         Set8       8  [{'apiName': 'Set8_Riftwalker', 'desc': '<row>...
# 10        Set8       8  [{'apiName': 'Set8_Civilian', 'desc': '민간인이 생존...
# 11        Set7       7  [{'apiName': 'Set7_Cannoneer', 'desc': '5번째 공격...
# 12        Set7       7  [{'apiName': 'Set7_Cannoneer', 'desc': '5번째 공격...
# 13        Set7       7  [{'apiName': 'Set7_Cannoneer', 'desc': '5번째 공격...
# 14        Set8       8  [{'apiName': 'Set8_Civilian', 'desc': '민간인이 생존...
# 15        Set8       8  [{'apiName': 'Set8_Riftwalker', 'desc': '<row>...
# 16        Set7       7  [{'apiName': 'Set7_Cannoneer', 'desc': '5번째 공격...
# 17        Set6       6  [{'apiName': 'Set6_Rivals', 'desc': '이 특성은 정확히...
# 18        Set6       6  [{'apiName': 'Set6_Rivals', 'desc': '이 특성은 정확히...
# 19        Set8       8  [{'apiName': 'Set8_Riftwalker', 'desc': '<row>...
# 20        Set6       6  [{'apiName': 'Set6_Rivals', 'desc': '이 특성은 정확히...
# 21        Set9       9  [{'apiName': 'Set9_Bastion', 'desc': '요새 챔피언이 ...
# 22        Set9       9  [{'apiName': 'Set9_Bastion', 'desc': '요새 챔피언이 ...

# %%
set9_champions = pd.DataFrame(*set_data.loc[set_data['mutator']=='TFTSet9']['champions'])
set9_champions.head()
# Out:
#                                              ability                 apiName  \
# 0  {'desc': '공허 생물이 현재 스테이지를 기준으로 추가 체력과 공격력을 얻습니...           TFT_Voidspawn
# 1  {'desc': '훈련 봇은 움직이거나 공격할 수 없으며 마성의 외모를 지닌 요들의...       TFT_TrainingDummy
# 2  {'desc': '이 고서를 상점에 끌어다 놓으면 상징이 가득한 무기고가 열립니다!...    TFT5_EmblemArmoryKey
# 3  {'desc': '이 아이템을 상점에 끌어다 놓으면 완성 아이템이 가득한 무기고가 ...  TFT_ArmoryKeyCompleted
# 4  {'desc': '이 아이템을 상점에 끌어다 놓으면 조합 아이템이 가득한 무기고가 ...  TFT_ArmoryKeyComponent
#
#             characterName  cost  \
# 0           TFT_VoidSpawn     1
# 1       TFT_TrainingDummy     1
# 2    TFT5_EmblemArmoryKey     8
# 3  TFT_ArmoryKeyCompleted     8
# 4  TFT_ArmoryKeyComponent     8
#
#                                                 icon       name  \
# 0   ASSETS/UX/TFT/ChampionSplashes/TFT_Voidspawn.dds      공허 생물
# 1  ASSETS/UX/TFT/ChampionSplashes/TFTDebug_Dummy.dds       훈련 봇
# 2  ASSETS/UX/TFT/ChampionSplashes/TFT5_EmblemArmo...     특성의 고서
# 3                                               None  완성 아이템 모루
# 4                                               None  조합 아이템 모루
#
#                                           squareIcon  \
# 0  ASSETS/UX/TFT/ChampionSplashes/TFT_Voidspawn_M...
# 1  ASSETS/UX/TFT/ChampionSplashes/TFTDebug_Dummy_...
# 2  ASSETS/UX/TFT/ChampionSplashes/TFT5_DraconicEg...
# 3                                               None
# 4                                               None
#
#                                                stats  \
# 0  {'armor': 20.0, 'attackSpeed': 0.8000000119209...
# 1  {'armor': 40.0, 'attackSpeed': 0.2000000029802...
# 2  {'armor': 10.0, 'attackSpeed': 1.0, 'critChanc...
# 3  {'armor': 10.0, 'attackSpeed': 1.0, 'critChanc...
# 4  {'armor': 10.0, 'attackSpeed': 1.0, 'critChanc...
#
#                                             tileIcon traits
# 0  ASSETS/Characters/TFT_VoidSpawn/HUD/Voidspawn_...     []
# 1  ASSETS/Characters/TFT_TrainingDummy/HUD/Icons2...     []
# 2  ASSETS/Characters/TFT5_EmblemArmoryKey/HUD/TFT...     []
# 3  ASSETS/Characters/TFT_ArmoryKeyCompleted/HUD/T...     []
# 4  ASSETS/Characters/TFT_ArmoryKeyComponent/HUD/T...     []

# %%
set9_champions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ability        88 non-null     object
#  1   apiName        88 non-null     object
#  2   characterName  88 non-null     object
#  3   cost           88 non-null     int64
#  4   icon           85 non-null     object
#  5   name           88 non-null     object
#  6   squareIcon     85 non-null     object
#  7   stats          88 non-null     object
#  8   tileIcon       88 non-null     object
#  9   traits         88 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 7.0+ KB

# %%
set9_traits = pd.DataFrame(*set_data.loc[set_data['mutator']=='TFTSet9']['traits'])
set9_traits.head()
# Out:
#            apiName                                               desc  \
# 0     Set9_Bastion  요새 챔피언이 방어력과 마법 저항력을 얻습니다. 이 효과는 전투 시작 후 @Dura...
# 1    Set9_Sorcerer  마법사는 추가 주문력을 얻습니다.<br><br>적이 마법사에게 피해를 입은 뒤 사망...
# 2  Set9_BandleCity  아군이 별 레벨 하나당 공격 속도를 @BonusAttackSpeed*100@% 얻습...
# 3     Set9_Deadeye  <spellPassive>고유:</spellPassive> 사거리 +@BonusRa...
# 4        Set9_Void  전장에 놓을 수 있는 공허 알을 획득합니다. 전투 시작 시 알이 말할 수 없는 공포...
#
#                                              effects  \
# 0  [{'maxUnits': 3, 'minUnits': 2, 'style': 1, 'v...
# 1  [{'maxUnits': 3, 'minUnits': 2, 'style': 1, 'v...
# 2  [{'maxUnits': 4, 'minUnits': 3, 'style': 1, 'v...
# 3  [{'maxUnits': 3, 'minUnits': 2, 'style': 1, 'v...
# 4  [{'maxUnits': 5, 'minUnits': 3, 'style': 1, 'v...
#
#                                                 icon  name
# 0  ASSETS/UX/TraitIcons/Trait_Icon_9_Bastion.TFT_...    요새
# 1     ASSETS/UX/TraitIcons/Trait_Icon_3_Sorcerer.tex   마법사
# 2       ASSETS/UX/TraitIcons/Trait_Icon_6_Yordle.tex    요들
# 3  ASSETS/UX/TraitIcons/Trait_Icon_9_Deadeye.TFT_...  백발백중
# 4  ASSETS/UX/TraitIcons/Trait_Icon_9_Void.TFT_Set...    공허

# %%
sets = pd.DataFrame(data_dragon['sets'])
sets
# Out:
#                                                            1  \
# champions  [{'ability': {'desc': '공허 생물이 현재 스테이지를 기준으로 추가...
# name                                              TutorialV2
# traits     [{'apiName': 'TFTTutorial_Hextech', 'desc': '전...
#
#                                                            6  \
# champions  [{'ability': {'desc': '공허 생물이 현재 스테이지를 기준으로 추가...
# name                                                    Set6
# traits     [{'apiName': 'Set6_Rivals', 'desc': '이 특성은 정확히...
#
#                                                            7  \
# champions  [{'ability': {'desc': '블라디미르가 대상에게 @ModifiedDa...
# name                                                    Set7
# traits     [{'apiName': 'Set7_Cannoneer', 'desc': '5번째 공격...
#
#                                                            8  \
# champions  [{'ability': {'desc': '사일러스가 사슬을 휘둘러 주변 적들에게 <...
# name                                                    Set8
# traits     [{'apiName': 'Set8_Riftwalker', 'desc': '<row>...
#
#                                                            9
# champions  [{'ability': {'desc': '공허 생물이 현재 스테이지를 기준으로 추가...
# name                                                    Set9
# traits     [{'apiName': 'Set9_Bastion', 'desc': '요새 챔피언이 ...

# %%
set9 = pd.DataFrame(sets['9'])
set9 = set9.transpose()

# %%
set9_champions =  pd.DataFrame(*set9['champions'])
set9_champions.head(20)
# Out:
#                                               ability                 apiName  \
# 0   {'desc': '공허 생물이 현재 스테이지를 기준으로 추가 체력과 공격력을 얻습니...           TFT_Voidspawn
# 1   {'desc': '훈련 봇은 움직이거나 공격할 수 없으며 마성의 외모를 지닌 요들의...       TFT_TrainingDummy
# 2   {'desc': '이 고서를 상점에 끌어다 놓으면 상징이 가득한 무기고가 열립니다!...    TFT5_EmblemArmoryKey
# 3   {'desc': '이 아이템을 상점에 끌어다 놓으면 완성 아이템이 가득한 무기고가 ...  TFT_ArmoryKeyCompleted
# 4   {'desc': '이 아이템을 상점에 끌어다 놓으면 조합 아이템이 가득한 무기고가 ...  TFT_ArmoryKeyComponent
# 5   {'desc': '이 아이템을 상점에 끌어다 놓으면 오른의 유물이 가득한 무기고가 ...       TFT_ArmoryKeyOrnn
# 6   {'desc': '@Duration@초 동안 <TFTBonus>@ModifiedAt...           TFT9_Tristana
# 7   {'desc': '방어 태세를 갖추며 <TFTBonus>@ModifiedShield...             TFT9_Irelia
# 8   {'desc': '@Duration@초 동안 변신해 <TFTBonus>@Modifi...             TFT9_Aatrox
# 9   {'desc': '현재 대상 주위의 적들로부터 정기를 빼앗으며 <magicDamag...               TFT9_Ahri
# 10  {'desc': '가장 멀리 있는 적을 향해 @NumBullets@회 연속 공격합니...             TFT9_Akshan
# 11  {'desc': '원뿔 범위에 @Shots@개의 화살을 발사합니다. 각 화살은 처음...               TFT9_Ashe
# 12  {'desc': '<spellPassive>기본 지속 효과:</spellPassiv...               TFT9_Azir
# 13  {'desc': '사거리 내 체력이 가장 낮은 적을 빠르게 <TFTBonus>@Mo...            TFT9_BelVeth
# 14  {'desc': '체력이 가장 낮은 근처 적에게 <magicDamage>@Total...            TFT9_ChoGath
# 15  {'desc': '현재 대상에게 <physicalDamage>@TotalDamage...             TFT9_Darius
# 16  {'desc': '지난 @RewindTime@초 동안 받은 피해량의 <scaleHe...               TFT9_Ekko
# 17  {'desc': '<TFTBonus>@ModifiedDuration@ (%i:sca...              TFT9_Garen
# 18  {'desc': '현재 대상 주변을 돌며 원뿔 범위를 @Snips@회 가위질해 적중...               TFT9_Gwen
# 19  {'desc': '가장 큰 적 무리를 향해 수류탄을 던집니다. 수류탄은 광범위하게 ...       TFT9_Heimerdinger
#
#              characterName  cost  \
# 0            TFT_VoidSpawn     1
# 1        TFT_TrainingDummy     1
# 2     TFT5_EmblemArmoryKey     8
# 3   TFT_ArmoryKeyCompleted     8
# 4   TFT_ArmoryKeyComponent     8
# 5        TFT_ArmoryKeyOrnn     8
# 6            TFT9_Tristana     1
# 7              TFT9_Irelia     1
# 8              TFT9_Aatrox     5
# 9                TFT9_Ahri     5
# 10             TFT9_Akshan     3
# 11               TFT9_Ashe     2
# 12               TFT9_Azir     4
# 13            TFT9_BelVeth     5
# 14            TFT9_ChoGath     1
# 15             TFT9_Darius     3
# 16               TFT9_Ekko     3
# 17              TFT9_Garen     3
# 18               TFT9_Gwen     4
# 19       TFT9_Heimerdinger     5
#
#                                                  icon        name  \
# 0    ASSETS/UX/TFT/ChampionSplashes/TFT_Voidspawn.dds       공허 생물
# 1   ASSETS/UX/TFT/ChampionSplashes/TFTDebug_Dummy.dds        훈련 봇
# 2   ASSETS/UX/TFT/ChampionSplashes/TFT5_EmblemArmo...      특성의 고서
# 3                                                None   완성 아이템 모루
# 4                                                None   조합 아이템 모루
# 5                                                None  오른의 아이템 모루
# 6   ASSETS/UX/TFT/ChampionSplashes/TFT9_Tristana.T...       트리스타나
# 7   ASSETS/UX/TFT/ChampionSplashes/TFT9_Irelia.TFT...        이렐리아
# 8   ASSETS/UX/TFT/ChampionSplashes/TFT9_Aatrox.TFT...        아트록스
# 9   ASSETS/UX/TFT/ChampionSplashes/TFT9_Ahri.TFT_S...          아리
# 10  ASSETS/UX/TFT/ChampionSplashes/TFT9_Akshan.TFT...         아크샨
# 11  ASSETS/UX/TFT/ChampionSplashes/TFT9_Ashe.TFT_S...          애쉬
# 12  ASSETS/UX/TFT/ChampionSplashes/TFT9_Azir.TFT_S...         아지르
# 13  ASSETS/UX/TFT/ChampionSplashes/TFT9_BelVeth.TF...         벨베스
# 14  ASSETS/UX/TFT/ChampionSplashes/TFT9_ChoGath.TF...         초가스
# 15  ASSETS/UX/TFT/ChampionSplashes/TFT9_Darius.TFT...        다리우스
# 16  ASSETS/UX/TFT/ChampionSplashes/TFT9_Ekko.TFT_S...          에코
# 17  ASSETS/UX/TFT/ChampionSplashes/TFT9_Garen.TFT_...          가렌
# 18  ASSETS/UX/TFT/ChampionSplashes/TFT9_Gwen.TFT_S...          그웬
# 19  ASSETS/UX/TFT/ChampionSplashes/TFT9_Heimerding...       하이머딩거
#
#                                            squareIcon  \
# 0   ASSETS/UX/TFT/ChampionSplashes/TFT_Voidspawn_M...
# 1   ASSETS/UX/TFT/ChampionSplashes/TFTDebug_Dummy_...
# 2   ASSETS/UX/TFT/ChampionSplashes/TFT5_DraconicEg...
# 3                                                None
# 4                                                None
# 5                                                None
# 6   ASSETS/UX/TFT/ChampionSplashes/TFT9_Tristana_M...
# 7   ASSETS/UX/TFT/ChampionSplashes/TFT9_Irelia_Mob...
# 8   ASSETS/UX/TFT/ChampionSplashes/TFT9_Aatrox_Mob...
# 9   ASSETS/UX/TFT/ChampionSplashes/TFT9_Ahri_Mobil...
# 10  ASSETS/UX/TFT/ChampionSplashes/TFT9_Akshan_Mob...
# 11  ASSETS/UX/TFT/ChampionSplashes/TFT9_Ashe_Mobil...
# 12  ASSETS/UX/TFT/ChampionSplashes/TFT9_Azir_Mobil...
# 13  ASSETS/UX/TFT/ChampionSplashes/TFT9_BelVeth_Mo...
# 14  ASSETS/UX/TFT/ChampionSplashes/TFT9_ChoGath_Mo...
# 15  ASSETS/UX/TFT/ChampionSplashes/TFT9_Darius_Mob...
# 16  ASSETS/UX/TFT/ChampionSplashes/TFT9_Ekko_Mobil...
# 17  ASSETS/UX/TFT/ChampionSplashes/TFT9_Garen_Mobi...
# 18  ASSETS/UX/TFT/ChampionSplashes/TFT9_Gwen_Mobil...
# 19  ASSETS/UX/TFT/ChampionSplashes/TFT9_Heimerding...
#
#                                                 stats  \
# 0   {'armor': 20.0, 'attackSpeed': 0.8000000119209...
# 1   {'armor': 40.0, 'attackSpeed': 0.2000000029802...
# 2   {'armor': 10.0, 'attackSpeed': 1.0, 'critChanc...
# 3   {'armor': 10.0, 'attackSpeed': 1.0, 'critChanc...
# 4   {'armor': 10.0, 'attackSpeed': 1.0, 'critChanc...
# 5   {'armor': 10.0, 'attackSpeed': 1.0, 'critChanc...
# 6   {'armor': 15.0, 'attackSpeed': 0.6999999880790...
# 7   {'armor': 40.0, 'attackSpeed': 0.6499999761581...
# 8   {'armor': 70.0, 'attackSpeed': 0.8000000119209...
# 9   {'armor': 40.0, 'attackSpeed': 0.8500000238418...
# 10  {'armor': 25.0, 'attackSpeed': 0.75, 'critChan...
# 11  {'armor': 20.0, 'attackSpeed': 0.75, 'critChan...
# 12  {'armor': 30.0, 'attackSpeed': 0.75, 'critChan...
# 13  {'armor': 50.0, 'attackSpeed': 0.8500000238418...
# 14  {'armor': 30.0, 'attackSpeed': 0.5, 'critChanc...
# 15  {'armor': 50.0, 'attackSpeed': 0.75, 'critChan...
# 16  {'armor': 40.0, 'attackSpeed': 0.8000000119209...
# 17  {'armor': 45.0, 'attackSpeed': 0.75, 'critChan...
# 18  {'armor': 50.0, 'attackSpeed': 0.8000000119209...
# 19  {'armor': 30.0, 'attackSpeed': 0.75, 'critChan...
#
#                                              tileIcon              traits
# 0   ASSETS/Characters/TFT_VoidSpawn/HUD/Voidspawn_...                  []
# 1   ASSETS/Characters/TFT_TrainingDummy/HUD/Icons2...                  []
# 2   ASSETS/Characters/TFT5_EmblemArmoryKey/HUD/TFT...                  []
# 3   ASSETS/Characters/TFT_ArmoryKeyCompleted/HUD/T...                  []
# 4   ASSETS/Characters/TFT_ArmoryKeyComponent/HUD/T...                  []
# 5   ASSETS/Characters/TFT_ArmoryKeyOrnn/HUD/TFT_Ar...                  []
# 6   ASSETS/Characters/TFT9_Tristana/HUD/TFT9_Trist...            [요들, 사수]
# 7   ASSETS/Characters/TFT9_Irelia/HUD/TFT9_Irelia_...        [아이오니아, 도전자]
# 8   ASSETS/Characters/TFT9_Aatrox/HUD/TFT9_Aatrox_...    [다르킨, 학살자, 전쟁기계]
# 9   ASSETS/Characters/TFT9_Ahri/HUD/TFT9_Ahri_Squa...        [아이오니아, 마법사]
# 10  ASSETS/Characters/TFT9_Akshan/HUD/TFT9_Akshan_...         [슈리마, 백발백중]
# 11  ASSETS/Characters/TFT9_Ashe/HUD/TFT9_Ashe_Squa...        [프렐요드, 백발백중]
# 12  ASSETS/Characters/TFT9_Azir/HUD/TFT9_Azir_Squa...          [슈리마, 책략가]
# 13  ASSETS/Characters/TFT9_BelVeth/HUD/TFT9_Belvet...            [공허, 여제]
# 14  ASSETS/Characters/TFT9_ChoGath/HUD/TFT9_ChoGat...           [공허, 난동꾼]
# 15  ASSETS/Characters/TFT9_Darius/HUD/TFT9_Darius_...         [녹서스, 전쟁기계]
# 16  ASSETS/Characters/TFT9_Ekko/HUD/TFT9_Ekko_Squa...     [자운, 필트오버, 불한당]
# 17  ASSETS/Characters/TFT9_Garen/HUD/TFT9_Garen_Sq...        [데마시아, 전쟁기계]
# 18  ASSETS/Characters/TFT9_Gwen/HUD/TFT9_Gwen_Squa...       [그림자 군도, 학살자]
# 19  ASSETS/Characters/TFT9_Heimerdinger/HUD/TFT9_H...  [필트오버, 요들, 발명의 대가]

# %%
set9_champions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ability        88 non-null     object
#  1   apiName        88 non-null     object
#  2   characterName  88 non-null     object
#  3   cost           88 non-null     int64
#  4   icon           85 non-null     object
#  5   name           88 non-null     object
#  6   squareIcon     85 non-null     object
#  7   stats          88 non-null     object
#  8   tileIcon       88 non-null     object
#  9   traits         88 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 7.0+ KB
